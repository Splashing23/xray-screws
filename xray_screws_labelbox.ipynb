# %%
import numpy as np
import cv2
import pandas as pd
import os
import labelbox
import json
import urllib.request

# %%
LB_API_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..WA-I984wLDZ0MiiCOYai1D7y9YfwZ51dy2CSZ_6xQN8'
PROJECT_NUMBER = "clv2u76f5064n071jbjoab056"
TASK_ID = "clxax49ji0apv07xr6uhzhpq7" # Update task number based on labelbox export

OUTPUT_FILE_PATH = os.path.join(os.path.expanduser("~"), "CS Projects\\ScrewClassification\\labelbox.json")
OUTPUT_IMAGE_DIR = os.path.join(os.path.expanduser("~"), "CS Projects\\ScrewClassification\\cropped_images_new")
LABEL_DATA = os.path.join(os.path.expanduser("~"), "CS Projects\\ScrewClassification\\xray-screws\\manufacturers-new.csv")

client = labelbox.Client(api_key = LB_API_KEY)

export_task = labelbox.ExportTask.get_task(client, TASK_ID)

export_task.get_stream(converter=labelbox.FileConverter(file_path=OUTPUT_FILE_PATH)).start()

xray_count = 0

screw_count = 0

# Create log file, clear if exists
with open('errors.txt', 'w'):
    pass

def log_to_file(error_message):
    with open('errors.txt', 'a') as f:
        f.write(error_message + '\n')

# Retrieving the original images from labelbox storage requires only the provided
# image URL, no special headers. 
def get_image_noheaders(image_url):

  with urllib.request.urlopen(image_url) as url:
        s = url.read()
  # Convert the downloaded bytes to a numpy array
  arr = np.asarray(bytearray(s), dtype=np.uint8)
  # Decode the numpy array as an image
  img = cv2.imdecode(arr, -1)

  return img


# Retrieving the mask image requires inclusion of provided headers in request
def get_image_with_headers(url):
  req = urllib.request.Request(url, headers=client.headers)

  # Download the image, convert it to a NumPy array, and then read it into OpenCV format
  resp = urllib.request.urlopen(req)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  
  return image


def find_manufacturer(accession_number):

  df = pd.read_csv(LABEL_DATA)
  row = df.loc[df['Accession Number'] == accession_number]

  if not row.empty:
      # Get the value from the 'Manufacturer' column
      manufacturer = row['Implant Manufacturer'].values[0] if not pd.isna(row['Implant Manufacturer'].values[0]) else "No manufacturer data"
  else:
      print("NO ACCESSION NUMBER MATCH")
      manufacturer = "No Accession Number Match"
      
  return manufacturer


def crop_to_mask(image_url, mask_url, mask_color):
  try:

    mask = get_image_with_headers(mask_url)
    image = get_image_noheaders(image_url)
    
    # reverse rgb to bgr for np
    bgr_color = mask_color[::-1]

    # Find the coordinates of the mask color pixels
    coords = np.where((mask == bgr_color).all(axis=2))

    # Find the minimum and maximum x and y values
    ymin, ymax = np.min(coords[0]), np.max(coords[0])
    xmin, xmax = np.min(coords[1]), np.max(coords[1])

    # Add padding to the bounding box
    padding = 20 
    xmin = max(0, xmin - padding)
    ymin = max(0, ymin - padding)
    xmax = min(mask.shape[1], xmax + padding)
    ymax = min(mask.shape[0], ymax + padding)

    # return the crop of the original image
    return image[ymin:ymax, xmin:xmax]


  except Exception as e:
    line_number = e.__traceback__.tb_lineno
    error_message = f"Error - Image Cropper: {e}, Image: {image_url}, Line: {line_number}"
    print(error_message)
    log_to_file(error_message)


def json_stream_handler(output):

  # Labelbox provides a composite mask image where each individual mask is a different color.
  # Get all of the RGB mask colors in a given image and loop through them to crop each individual mask out.

  try:

    data = json.loads(output.json_str)

    image_id = data['data_row']["global_key"]

    # For debuging problem images...
    # if image_id in ["117373809_00.jpg"]:
    #    print(data)

    accession_number = data["metadata_fields"][0]["value"]
    image_url = data["data_row"]["row_data"]  
    masks = data["projects"][PROJECT_NUMBER]["labels"][0]["annotations"]["objects"]
    mask_url = masks[0]["composite_mask"]["url"]
    mask_colors = [item["composite_mask"]["color_rgb"] for item in masks]
    # dataset_id = data["data_row"]["details"]["dataset_id"]
    # row_id = data["data_row"]["id"]

    # Make manufacturer directory if it doesnt exist
    manufacturer = find_manufacturer(accession_number)
    manufacturer_dir = os.path.join(OUTPUT_IMAGE_DIR, manufacturer)
    os.makedirs(manufacturer_dir, exist_ok=True)

    # Make accession number directory if it doesn't exist
    accession_dir = os.path.join(manufacturer_dir, accession_number)
    os.makedirs(accession_dir, exist_ok=True)
    
    for i, color in enumerate(mask_colors):
        
        # Strip the file extension from image_id and add a counter
        image_id_base = os.path.splitext(image_id)[0]
        image_id_new = f"{image_id_base}_{i}.jpg"
        # print(image_id_new)

        img_path = os.path.join(accession_dir, image_id_new)

        cropped_image = crop_to_mask(image_url, mask_url, color)

        cv2.imwrite(img_path, cropped_image)
        # print("Image saved...")
        global screw_count
        screw_count += 1
    
    # Logs
    global xray_count
    xray_count += 1
    print('**********************')
    print("Manufacturer: ", manufacturer)
    print("Accession Number: ", accession_number)
    print("xray count: ", xray_count)
    print("screw count: ", screw_count)

  except Exception as e:
    line_number = e.__traceback__.tb_lineno
    error_message = f"Error - Stream Handler: {e}, Image: {image_id}, Line: {line_number}"
    print(error_message)
    log_to_file(error_message)


# Stream the file to stdout
export_task.get_stream().start(stream_handler=json_stream_handler)
log_to_file("xray count: " + str(xray_count))
log_to_file("Screw count: " + str(screw_count))
print("stream handler finished")
# Out:
# Error - Stream Handler: 'Accession Number', Image: 113292680_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115213728_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116788885_04.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114949278_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116788885_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115213728_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115213728_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116788885_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113581075_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114949278_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116741929_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114949278_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116741929_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116788885_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116741929_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116788885_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115213728_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113581075_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117134345_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116077251_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116457066_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116457066_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116077251_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3969254_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117277863_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117115093_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117115093_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116338696_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116338696_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116338696_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113581075_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117115093_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113292680_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116338696_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115304998_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115304998_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114949278_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115304998_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117373809_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117373809_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114242758_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114242758_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117373809_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117134345_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115725428_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114019166_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115725428_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116975907_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114019166_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116741929_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116975907_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3969726_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115237299_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3969254_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3969726_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3969726_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115237299_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116352691_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117082961_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116352691_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115183565_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117082961_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116878388_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116878388_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114740757_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114568864_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114740757_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113797571_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 4016161_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113797571_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116457066_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113797571_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113797571_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117277863_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114634343_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116667233_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116601677_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116667233_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116601677_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117268317_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116601677_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114568864_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115304998_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117268317_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115269638_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117068627_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116352691_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114339822_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115183565_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116387610_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114339822_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116387610_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115300834_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115913943_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116352691_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115780309_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 4016161_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115300834_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114037105_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113609982_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114019166_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115780309_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113609982_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113302241_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113846513_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114634343_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113302241_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114037105_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115183565_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113846513_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116133611_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116133611_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116133611_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114705270_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113846513_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113846513_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117411567_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115300834_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115304097_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114705270_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 115269638_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114705270_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117411567_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114088480_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114511748_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 117068627_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116765111_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114879990_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114511748_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3977533_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114879990_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116083628_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114879990_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114028351_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114028351_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116667233_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116083628_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 3977533_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 114028351_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 116317936_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 
03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109751859_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 108982631_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 110428441_05.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112793746_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 110075412_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 110075412_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112793746_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112793746_04.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109249189_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109249189_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109113927_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112793746_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109113927_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111108381_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111108381_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109098234_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111108381_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109114216_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109113927_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 110162254_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109114216_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109970933_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111108381_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109970933_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109970933_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109970302_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109970302_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111968462_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113118311_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 113118311_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112166691_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109415488_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111968462_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 109415488_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112166691_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111968462_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112509706_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112509706_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112509706_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111242923_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111968462_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111242923_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112166691_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111242923_03.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112611906_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112199688_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111242923_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112611906_02.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111790905_01.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 112199688_00.jpg, Line: 126
# Error - Stream Handler: 'Accession Number', Image: 111790905_00.jpg, Line: 126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 167
#     163     log_to_file(error_message)
#     166 # Stream the file to stdout
# --> 167 export_task.get_stream().start(stream_handler=json_stream_handler)
#     168 log_to_file("xray count: " + str(xray_count))
#     169 log_to_file("Screw count: " + str(screw_count))
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\schema\export_task.py:452, in Stream.start(self, stream_handler)
#     448 """Starts streaming the result data.
#     449 Calls the stream_handler for each result.
#     450 """
#     451 # this calls the __iter__ method, which in turn calls the _fetch method
# --> 452 for output in self:
#     453     if stream_handler:
#     454         stream_handler(output)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\schema\export_task.py:416, in Stream.__iter__(self)
#     415 def __iter__(self):
# --> 416     yield from self._fetch()
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\schema\export_task.py:427, in Stream._fetch(self)
#     425 stream = self._reader.read()
#     426 with self._converter as converter:
# --> 427     for file_info, raw_data in stream:
#     428         for output in converter.convert(
#     429                 Converter.ConverterInputArgs(self._ctx, file_info,
#     430                                              raw_data)):
#     431             yield output
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\schema\export_task.py:397, in _MultiGCSFileReader.read(self)
#     395 file_info, raw_data = result
#     396 yield file_info, raw_data
# --> 397 result = self._retrieval_strategy.get_next_chunk()
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\schema\export_task.py:284, in FileRetrieverByOffset.get_next_chunk(self)
#     270 query = (
#     271     f"query GetExportFileFromOffsetPyApi"
#     272     f"($where: WhereUniqueIdInput, $streamType: TaskStreamType!, $offset: UInt64!)"
#    (...)
#     275     f"{{offsets {{start end}} lines {{start end}} file}}"
#     276     f"}}}}")
#     277 variables = {
#     278     "where": {
#     279         "id": self._ctx.task_id
#    (...)
#     282     "offset": str(self._current_offset),
#     283 }
# --> 284 file_info, file_content = self._get_file_content(
#     285     query, variables, "exportFileFromOffset")
#     286 if self._current_line is None:
#     287     self._current_line = self._find_line_at_offset(
#     288         file_content, self._current_offset - file_info.offsets.start)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\schema\export_task.py:216, in FileRetrieverStrategy._get_file_content(self, query, variables, result_field_name)
#     212 def _get_file_content(
#     213         self, query: str, variables: dict,
#     214         result_field_name: str) -> Tuple[_MetadataFileInfo, str]:
#     215     """Runs the query."""
# --> 216     res = self._ctx.client.execute(query, variables, error_log_key="errors")
#     217     res = res["task"][result_field_name]
#     218     file_info = _MetadataFileInfo(**res) if res else None
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\labelbox\client.py:200, in Client.execute(self, query, params, data, files, timeout, experimental, error_log_key)
#     196         request.update({'files': files})
#     197         request['headers'] = {
#     198             'Authorization': self.headers['Authorization']
#     199         }
# --> 200     response = requests.post(**request)
#     201     logger.debug("Response: %s", response.text)
#     202 except requests.exceptions.Timeout as e:
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\medev\anaconda3\envs\ScrewClassification\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
