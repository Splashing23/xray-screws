# %%
import numpy as np
import cv2
import pandas as pd
import os
import labelbox
import json
import urllib.request

# %%
LB_API_KEY = '<API_KEY>'
PROJECT_NUMBER = "clv2u76f5064n071jbjoab056"
TASK_ID = "clw0up26r029z07ybceb8c8oh" # Update task number based on labelbox export

OUTPUT_FILE_PATH = os.path.join(os.path.expanduser("~"), "Data/output/labelbox.json")
OUTPUT_IMAGE_DIR = os.path.join(os.path.expanduser("~"), "Data/output/cropped_images")
LABEL_DATA = os.path.join(os.path.expanduser("~"), "Data/manufacturers.csv")

client = labelbox.Client(api_key = LB_API_KEY)

export_task = labelbox.ExportTask.get_task(client, TASK_ID)

export_task.get_stream(converter=labelbox.FileConverter(file_path=OUTPUT_FILE_PATH)).start()

xray_count = 0

screw_count = 0

# Create log file, clear if exists
with open('errors.txt', 'w'):
    pass

def log_to_file(error_message):
    with open('errors.txt', 'a') as f:
        f.write(error_message + '\n')

# Retrieving the original images from labelbox storage requires only the provided
# image URL, no special headers. 
def get_image_noheaders(image_url):

  with urllib.request.urlopen(image_url) as url:
        s = url.read()
  # Convert the downloaded bytes to a numpy array
  arr = np.asarray(bytearray(s), dtype=np.uint8)
  # Decode the numpy array as an image
  img = cv2.imdecode(arr, -1)

  return img


# Retrieving the mask image requires inclusion of provided headers in request
def get_image_with_headers(url):
  req = urllib.request.Request(url, headers=client.headers)

  # Download the image, convert it to a NumPy array, and then read it into OpenCV format
  resp = urllib.request.urlopen(req)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  
  return image


def find_manufacturer(accession_number):

  df = pd.read_csv(LABEL_DATA)
  row = df.loc[df['Accession Number'] == accession_number]

  if not row.empty:
      # Get the value from the 'Manufacturer' column
      manufacturer = row['Implant Manufacturer'].values[0] if not pd.isna(row['Implant Manufacturer'].values[0]) else "No manufacturer data"
  else:
      print("NO ACCESSION NUMBER MATCH")
      manufacturer = "No Accession Number Match"
      
  return manufacturer


def crop_to_mask(image_url, mask_url, mask_color):
  try:

    mask = get_image_with_headers(mask_url)
    image = get_image_noheaders(image_url)
    
    # reverse rgb to bgr for np
    bgr_color = mask_color[::-1]

    # Find the coordinates of the mask color pixels
    coords = np.where((mask == bgr_color).all(axis=2))

    # Find the minimum and maximum x and y values
    ymin, ymax = np.min(coords[0]), np.max(coords[0])
    xmin, xmax = np.min(coords[1]), np.max(coords[1])

    # Add padding to the bounding box
    padding = 20 
    xmin = max(0, xmin - padding)
    ymin = max(0, ymin - padding)
    xmax = min(mask.shape[1], xmax + padding)
    ymax = min(mask.shape[0], ymax + padding)

    # return the crop of the original image
    return image[ymin:ymax, xmin:xmax]


  except Exception as e:
    line_number = e.__traceback__.tb_lineno
    error_message = f"Error - Image Cropper: {e}, Image: {image_url}, Line: {line_number}"
    print(error_message)
    log_to_file(error_message)


def json_stream_handler(output):

  # Labelbox provides a composite mask image where each individual mask is a different color.
  # Get all of the RGB mask colors in a given image and loop through them to crop each individual mask out.

  try:

    data = json.loads(output.json_str)

    image_id = data['data_row']["global_key"]

    # For debuging problem images...
    # if image_id in ["117373809_00.jpg"]:
    #    print(data)

    accession_number = data["metadata_fields"][0]["value"]
    image_url = data["data_row"]["row_data"]  
    masks = data["projects"][PROJECT_NUMBER]["labels"][0]["annotations"]["objects"]
    mask_url = masks[0]["composite_mask"]["url"]
    mask_colors = [item["composite_mask"]["color_rgb"] for item in masks]
    # dataset_id = data["data_row"]["details"]["dataset_id"]
    # row_id = data["data_row"]["id"]

    # Make manufacturer directory if it doesnt exist
    manufacturer = find_manufacturer(accession_number)
    manufacturer_dir = os.path.join(OUTPUT_IMAGE_DIR, manufacturer)
    os.makedirs(manufacturer_dir, exist_ok=True)

    # Make accession number directory if it doesn't exist
    accession_dir = os.path.join(manufacturer_dir, accession_number)
    os.makedirs(accession_dir, exist_ok=True)
    
    for i, color in enumerate(mask_colors):
        
        # Strip the file extension from image_id and add a counter
        image_id_base = os.path.splitext(image_id)[0]
        image_id_new = f"{image_id_base}_{i}.jpg"
        # print(image_id_new)

        img_path = os.path.join(accession_dir, image_id_new)

        cropped_image = crop_to_mask(image_url, mask_url, color)

        cv2.imwrite(img_path, cropped_image)
        # print("Image saved...")
        global screw_count
        screw_count += 1
    
    # Logs
    global xray_count
    xray_count += 1
    print('**********************')
    print("Manufacturer: ", manufacturer)
    print("Accession Number: ", accession_number)
    print("xray count: ", xray_count)
    print("screw count: ", screw_count)

  except Exception as e:
    line_number = e.__traceback__.tb_lineno
    error_message = f"Error - Stream Handler: {e}, Image: {image_id}, Line: {line_number}"
    print(error_message)
    log_to_file(error_message)


# Stream the file to stdout
export_task.get_stream().start(stream_handler=json_stream_handler)
log_to_file("xray count: " + xray_count)
log_to_file("Screw count: " + screw_count)
print("stream handler finished")
# Out:
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  113292680
# xray count:  1
# screw count:  14
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115213728
# xray count:  2
# screw count:  18
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788885
# xray count:  3
# screw count:  37
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114949278
# xray count:  4
# screw count:  39
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788885
# xray count:  5
# screw count:  47
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115213728
# xray count:  6
# screw count:  55
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115213728
# xray count:  7
# screw count:  63
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788885
# xray count:  8
# screw count:  69
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113581075
# xray count:  9
# screw count:  77
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114949278
# xray count:  10
# screw count:  79
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116741929
# xray count:  11
# screw count:  83
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114949278
# xray count:  12
# screw count:  87
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116741929
# xray count:  13
# screw count:  88
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788885
# xray count:  14
# screw count:  100
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116741929
# xray count:  15
# screw count:  108
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788885
# xray count:  16
# screw count:  113
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115213728
# xray count:  17
# screw count:  117
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113581075
# xray count:  18
# screw count:  120
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117134345
# xray count:  19
# screw count:  135
# Error - Stream Handler: list index out of range, Image: 114907468_01.jpg, Line: 120
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116077251
# xray count:  20
# screw count:  143
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116457066
# xray count:  21
# screw count:  147
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116457066
# xray count:  22
# screw count:  152
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116077251
# xray count:  23
# screw count:  156
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3969254
# xray count:  24
# screw count:  161
# **********************
# Manufacturer:  Synthes Spine
# Accession Number:  117277863
# xray count:  25
# screw count:  165
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117115093
# xray count:  26
# screw count:  177
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117115093
# xray count:  27
# screw count:  181
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116338696
# xray count:  28
# screw count:  186
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116338696
# xray count:  29
# screw count:  192
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116338696
# xray count:  30
# screw count:  194
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113581075
# xray count:  31
# screw count:  198
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117115093
# xray count:  32
# screw count:  203
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  113292680
# xray count:  33
# screw count:  212
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116338696
# xray count:  34
# screw count:  215
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115304998
# xray count:  35
# screw count:  227
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115304998
# xray count:  36
# screw count:  239
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114949278
# xray count:  37
# screw count:  243
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115304998
# xray count:  38
# screw count:  253
# **********************
# Manufacturer:  Synthes Spine
# Accession Number:  117373809
# xray count:  39
# screw count:  262
# **********************
# Manufacturer:  Synthes Spine
# Accession Number:  117373809
# xray count:  40
# screw count:  268
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114242758
# xray count:  41
# screw count:  272
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114242758
# xray count:  42
# screw count:  280
# Error - Image Cropper: zero-size array to reduction operation minimum which has no identity, Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2F8bcb3ab3-361c-4160-c95f-3ffaaa389ee9-00.jpg?Expires=1715442443762&KeyName=labelbox-assets-key-3&Signature=kg8VNUsWzGAuWsZlz4nDdAHk4aI, Line: 81
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 117373809_00.jpg, Line: 145
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117134345
# xray count:  43
# screw count:  302
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115725428
# xray count:  44
# screw count:  314
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114019166
# xray count:  45
# screw count:  318
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115725428
# xray count:  46
# screw count:  326
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116975907
# xray count:  47
# screw count:  336
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114019166
# xray count:  48
# screw count:  344
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116741929
# xray count:  49
# screw count:  348
# Error - Stream Handler: list index out of range, Image: 115725428_02.jpg, Line: 120
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116975907
# xray count:  50
# screw count:  362
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3969726
# xray count:  51
# screw count:  372
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115237299
# xray count:  52
# screw count:  390
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3969254
# xray count:  53
# screw count:  399
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3969726
# xray count:  54
# screw count:  409
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3969726
# xray count:  55
# screw count:  414
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115237299
# xray count:  56
# screw count:  422
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116352691
# xray count:  57
# screw count:  426
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117082961
# xray count:  58
# screw count:  429
# Error - Stream Handler: list index out of range, Image: 114907468_00.jpg, Line: 120
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116352691
# xray count:  59
# screw count:  437
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115183565
# xray count:  60
# screw count:  443
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117082961
# xray count:  61
# screw count:  449
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116878388
# xray count:  62
# screw count:  455
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116878388
# xray count:  63
# screw count:  460
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114740757
# xray count:  64
# screw count:  467
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114568864
# xray count:  65
# screw count:  471
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114740757
# xray count:  66
# screw count:  475
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113797571
# xray count:  67
# screw count:  478
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  4016161
# xray count:  68
# screw count:  492
# Error - Stream Handler: list index out of range, Image: 116338696_04.jpg, Line: 120
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113797571
# xray count:  69
# screw count:  497
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116457066
# xray count:  70
# screw count:  505
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113797571
# xray count:  71
# screw count:  515
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113797571
# xray count:  72
# screw count:  525
# **********************
# Manufacturer:  Synthes Spine
# Accession Number:  117277863
# xray count:  73
# screw count:  533
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  114634343
# xray count:  74
# screw count:  541
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116667233
# xray count:  75
# screw count:  545
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116601677
# xray count:  76
# screw count:  552
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116667233
# xray count:  77
# screw count:  556
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116601677
# xray count:  78
# screw count:  561
# **********************
# Manufacturer:  Johnson & Johnson Health Care Syste
# Accession Number:  117268317
# xray count:  79
# screw count:  571
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116601677
# xray count:  80
# screw count:  576
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114568864
# xray count:  81
# screw count:  586
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115304998
# xray count:  82
# screw count:  596
# **********************
# Manufacturer:  Johnson & Johnson Health Care Syste
# Accession Number:  117268317
# xray count:  83
# screw count:  601
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115269638
# xray count:  84
# screw count:  609
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117068627
# xray count:  85
# screw count:  617
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116352691
# xray count:  86
# screw count:  625
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114339822
# xray count:  87
# screw count:  631
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115183565
# xray count:  88
# screw count:  637
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116387610
# xray count:  89
# screw count:  646
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114339822
# xray count:  90
# screw count:  649
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116387610
# xray count:  91
# screw count:  658
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115300834
# xray count:  92
# screw count:  663
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115913943
# xray count:  93
# screw count:  665
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116352691
# xray count:  94
# screw count:  669
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115780309
# xray count:  95
# screw count:  674
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  4016161
# xray count:  96
# screw count:  682
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115300834
# xray count:  97
# screw count:  687
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114037105
# xray count:  98
# screw count:  689
# Error - Stream Handler: list index out of range, Image: 114037105_01.jpg, Line: 120
# **********************
# Manufacturer:  Core Link Llc
# Accession Number:  113609982
# xray count:  99
# screw count:  694
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114019166
# xray count:  100
# screw count:  698
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115780309
# xray count:  101
# screw count:  707
# **********************
# Manufacturer:  Core Link Llc
# Accession Number:  113609982
# xray count:  102
# screw count:  710
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113302241
# xray count:  103
# screw count:  712
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113846513
# xray count:  104
# screw count:  716
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  114634343
# xray count:  105
# screw count:  720
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113302241
# xray count:  106
# screw count:  724
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114037105
# xray count:  107
# screw count:  732
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115183565
# xray count:  108
# screw count:  744
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113846513
# xray count:  109
# screw count:  750
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116133611
# xray count:  110
# screw count:  754
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116133611
# xray count:  111
# screw count:  756
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116133611
# xray count:  112
# screw count:  758
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114705270
# xray count:  113
# screw count:  763
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113846513
# xray count:  114
# screw count:  769
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  113846513
# xray count:  115
# screw count:  773
# **********************
# Manufacturer:  Seaspine Northstar
# Accession Number:  117411567
# xray count:  116
# screw count:  787
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115300834
# xray count:  117
# screw count:  790
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115304097
# xray count:  118
# screw count:  798
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114705270
# xray count:  119
# screw count:  801
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115269638
# xray count:  120
# screw count:  805
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114705270
# xray count:  121
# screw count:  810
# **********************
# Manufacturer:  Seaspine Northstar
# Accession Number:  117411567
# xray count:  122
# screw count:  817
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114088480
# xray count:  123
# screw count:  823
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  114511748
# xray count:  124
# screw count:  825
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117068627
# xray count:  125
# screw count:  829
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116765111
# xray count:  126
# screw count:  835
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114879990
# xray count:  127
# screw count:  839
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  114511748
# xray count:  128
# screw count:  843
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3977533
# xray count:  129
# screw count:  848
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114879990
# xray count:  130
# screw count:  850
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116083628
# xray count:  131
# screw count:  860
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114879990
# xray count:  132
# screw count:  862
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114028351
# xray count:  133
# screw count:  864
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114028351
# xray count:  134
# screw count:  868
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116667233
# xray count:  135
# screw count:  876
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116083628
# xray count:  136
# screw count:  881
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3977533
# xray count:  137
# screw count:  891
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114028351
# xray count:  138
# screw count:  893
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116317936
# xray count:  139
# screw count:  901
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116317936
# xray count:  140
# screw count:  907
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115349880
# xray count:  141
# screw count:  911
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115913943
# xray count:  142
# screw count:  915
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116765111
# xray count:  143
# screw count:  927
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116170167
# xray count:  144
# screw count:  930
# **********************
# Manufacturer:  Alphatec Spine
# Accession Number:  116514418
# xray count:  145
# screw count:  934
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115349880
# xray count:  146
# screw count:  944
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116170167
# xray count:  147
# screw count:  946
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116170167
# xray count:  148
# screw count:  949
# **********************
# Manufacturer:  Alphatec Spine
# Accession Number:  116514418
# xray count:  149
# screw count:  956
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113720301
# xray count:  150
# screw count:  959
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113720301
# xray count:  151
# screw count:  962
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116317936
# xray count:  152
# screw count:  968
# **********************
# Manufacturer:  Alphatec Spine
# Accession Number:  116514418
# xray count:  153
# screw count:  976
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116170167
# xray count:  154
# screw count:  996
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114871761
# xray count:  155
# screw count:  1006
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114389190
# xray count:  156
# screw count:  1013
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114322642
# xray count:  157
# screw count:  1022
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114322642
# xray count:  158
# screw count:  1036
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114088480
# xray count:  159
# screw count:  1039
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115485274
# xray count:  160
# screw count:  1044
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114389190
# xray count:  161
# screw count:  1048
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114871761
# xray count:  162
# screw count:  1053
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788889
# xray count:  163
# screw count:  1061
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115349880
# xray count:  164
# screw count:  1069
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115349880
# xray count:  165
# screw count:  1074
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116924613
# xray count:  166
# screw count:  1077
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115304097
# xray count:  167
# screw count:  1081
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788889
# xray count:  168
# screw count:  1088
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115485274
# xray count:  169
# screw count:  1091
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115673608
# xray count:  170
# screw count:  1095
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116924613
# xray count:  171
# screw count:  1101
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115673608
# xray count:  172
# screw count:  1105
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116317936
# xray count:  173
# screw count:  1109
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115485274
# xray count:  174
# screw count:  1110
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117135857
# xray count:  175
# screw count:  1113
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116446748
# xray count:  176
# screw count:  1121
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114075826
# xray count:  177
# screw count:  1127
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115673608
# xray count:  178
# screw count:  1135
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116788889
# xray count:  179
# screw count:  1153
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114075826
# xray count:  180
# screw count:  1160
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116658208
# xray count:  181
# screw count:  1164
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116658208
# xray count:  182
# screw count:  1166
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116658208
# xray count:  183
# screw count:  1168
# **********************
# Manufacturer:  Core Link Llc
# Accession Number:  115954928
# xray count:  184
# screw count:  1189
# **********************
# Manufacturer:  Core Link Llc
# Accession Number:  115954928
# xray count:  185
# screw count:  1198
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116392459
# xray count:  186
# screw count:  1203
# **********************
# Manufacturer:  Core Link Llc
# Accession Number:  115954928
# xray count:  187
# screw count:  1211
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114075826
# xray count:  188
# screw count:  1216
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116392459
# xray count:  189
# screw count:  1224
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116446748
# xray count:  190
# screw count:  1232
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117050436
# xray count:  191
# screw count:  1238
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114458194
# xray count:  192
# screw count:  1240
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117050436
# xray count:  193
# screw count:  1246
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114458194
# xray count:  194
# screw count:  1250
# **********************
# Manufacturer:  Sea Spine Inc.
# Accession Number:  117246037
# xray count:  195
# screw count:  1259
# **********************
# Manufacturer:  Sea Spine Inc.
# Accession Number:  117246037
# xray count:  196
# screw count:  1275
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116050737
# xray count:  197
# screw count:  1283
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114048599
# xray count:  198
# screw count:  1289
# **********************
# Manufacturer:  Sea Spine Inc.
# Accession Number:  117246037
# xray count:  199
# screw count:  1295
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114048599
# xray count:  200
# screw count:  1298
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115735425
# xray count:  201
# screw count:  1302
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115735425
# xray count:  202
# screw count:  1304
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116050737
# xray count:  203
# screw count:  1308
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116180262
# xray count:  204
# screw count:  1316
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116141150
# xray count:  205
# screw count:  1320
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114365005
# xray count:  206
# screw count:  1328
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114942777
# xray count:  207
# screw count:  1334
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117174308
# xray count:  208
# screw count:  1347
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117174308
# xray count:  209
# screw count:  1360
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114365005
# xray count:  210
# screw count:  1364
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117174308
# xray count:  211
# screw count:  1376
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114942777
# xray count:  212
# screw count:  1385
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117135857
# xray count:  213
# screw count:  1389
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117174308
# xray count:  214
# screw count:  1401
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115695442
# xray count:  215
# screw count:  1405
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113789273
# xray count:  216
# screw count:  1414
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  117087287
# xray count:  217
# screw count:  1418
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  117087287
# xray count:  218
# screw count:  1420
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  113789273
# xray count:  219
# screw count:  1429
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114366832
# xray count:  220
# screw count:  1431
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  117135857
# xray count:  221
# screw count:  1439
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114366832
# xray count:  222
# screw count:  1443
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  117050436
# xray count:  223
# screw count:  1455
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116924613
# xray count:  224
# screw count:  1461
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  4004892
# xray count:  225
# screw count:  1468
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  113562712
# xray count:  226
# screw count:  1480
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  4004892
# xray count:  227
# screw count:  1491
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115695442
# xray count:  228
# screw count:  1499
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  4004892
# xray count:  229
# screw count:  1519
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115726282
# xray count:  230
# screw count:  1525
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115726282
# xray count:  231
# screw count:  1530
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116180262
# xray count:  232
# screw count:  1534
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115191230
# xray count:  233
# screw count:  1543
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116141150
# xray count:  234
# screw count:  1551
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3954883
# xray count:  235
# screw count:  1563
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115191230
# xray count:  236
# screw count:  1581
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116392459
# xray count:  237
# screw count:  1586
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115328120
# xray count:  238
# screw count:  1593
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115191230
# xray count:  239
# screw count:  1610
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114653836
# xray count:  240
# screw count:  1614
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115032809
# xray count:  241
# screw count:  1633
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116944690
# xray count:  242
# screw count:  1647
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3954883
# xray count:  243
# screw count:  1657
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116944690
# xray count:  244
# screw count:  1663
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115328120
# xray count:  245
# screw count:  1675
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114008942
# xray count:  246
# screw count:  1684
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115032809
# xray count:  247
# screw count:  1696
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116944690
# xray count:  248
# screw count:  1701
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115587904
# xray count:  249
# screw count:  1703
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3952985
# xray count:  250
# screw count:  1705
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114008942
# xray count:  251
# screw count:  1709
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  116946048
# xray count:  252
# screw count:  1723
# **********************
# Manufacturer:  DePuy Spine, Inc.
# Accession Number:  3952985
# xray count:  253
# screw count:  1727
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114999073
# xray count:  254
# screw count:  1735
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115923116
# xray count:  255
# screw count:  1739
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114653836
# xray count:  256
# screw count:  1747
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  115973006
# xray count:  257
# screw count:  1751
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115923116
# xray count:  258
# screw count:  1753
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  115973006
# xray count:  259
# screw count:  1757
# **********************
# Manufacturer:  Medtronic Sofafmor Danek Inc
# Accession Number:  114212941
# xray count:  260
# screw count:  1775
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115450751
# xray count:  261
# screw count:  1778
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115450751
# xray count:  262
# screw count:  1785
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115998807
# xray count:  263
# screw count:  1789
# Error - Stream Handler: list index out of range, Image: 116452937_00.jpg, Line: 120
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116452937
# xray count:  264
# screw count:  1797
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116452937
# xray count:  265
# screw count:  1800
# **********************
# Manufacturer:  Medtronic Sofafmor Danek Inc
# Accession Number:  114212941
# xray count:  266
# screw count:  1810
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114255427
# xray count:  267
# screw count:  1818
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  115973006
# xray count:  268
# screw count:  1826
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115998807
# xray count:  269
# screw count:  1828
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116414745
# xray count:  270
# screw count:  1832
# **********************
# Manufacturer:  Medtronic Inc
# Accession Number:  116946048
# xray count:  271
# screw count:  1846
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116414745
# xray count:  272
# screw count:  1852
# **********************
# Manufacturer:  Medtronic Sofamor Danek Inc
# Accession Number:  116452937
# xray count:  273
# screw count:  1856
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116414745
# xray count:  274
# screw count:  1861
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115355607
# xray count:  275
# screw count:  1866
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116414745
# xray count:  276
# screw count:  1871
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115355607
# xray count:  277
# screw count:  1876
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114266257
# xray count:  278
# screw count:  1880
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114266257
# xray count:  279
# screw count:  1890
# **********************
# Manufacturer:  Core Link Llc
# Accession Number:  113760260
# xray count:  280
# screw count:  1897
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114255427
# xray count:  281
# screw count:  1901
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114059577
# xray count:  282
# screw count:  1905
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114059577
# xray count:  283
# screw count:  1911
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116299495
# xray count:  284
# screw count:  1927
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115125674
# xray count:  285
# screw count:  1931
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114424774
# xray count:  286
# screw count:  1939
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115690246
# xray count:  287
# screw count:  1947
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115355607
# xray count:  288
# screw count:  1957
# Error - Stream Handler: list index out of range, Image: 116452937_03.jpg, Line: 120
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  114424774
# xray count:  289
# screw count:  1961
# **********************
# Manufacturer:  Orthofix Inc
# Accession Number:  115587904
# xray count:  290
# screw count:  1965
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114529110
# xray count:  291
# screw count:  1968
# **********************
# Manufacturer:  Sea Spine Inc
# Accession Number:  114529110
# xray count:  292
# screw count:  1974
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  113562712
# xray count:  293
# screw count:  1986
# Error - Image Cropper: HTTP Error 520: , Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2Fde6ae650-3fe2-d4ce-7637-028c8f703b64-03.jpg?Expires=1715442443958&KeyName=labelbox-assets-key-3&Signature=wCBKI4oGTJqlTDkgQh0pPOxuhes, Line: 71
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 114266257_03.jpg, Line: 145
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115690246
# xray count:  294
# screw count:  1990
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  115923116
# xray count:  295
# screw count:  1992
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114999073
# xray count:  296
# screw count:  2000
# **********************
# Manufacturer:  Nuvasive
# Accession Number:  116299495
# xray count:  297
# screw count:  2016
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  115125674
# xray count:  298
# screw count:  2018
# **********************
# Manufacturer:  Stryker Spine
# Accession Number:  114266257
# xray count:  299
# screw count:  2023
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 168
#     166 # Stream the file to stdout
#     167 export_task.get_stream().start(stream_handler=json_stream_handler)
# --> 168 log_to_file("xray count: ", xray_count)
#     169 log_to_file("Screw count: ", screw_count)
#     170 print("stream handler finished")
#
# TypeError: log_to_file() takes 1 positional argument but 2 were given
